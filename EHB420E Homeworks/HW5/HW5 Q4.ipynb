# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\halit.erdogan\Downloads\Ship.xlsx')

# %%
df
# Out:
#             Ship Unnamed: 1 Unnamed: 2  \
# 0    PassengerId   Survived     Pclass
# 1              1          0          3
# 2              2          1          1
# 3              3          1          3
# 4              4          1          1
# ..           ...        ...        ...
# 887          887          0          2
# 888          888          1          1
# 889          889          0          3
# 890          890          1          1
# 891          891          0          3
#
#                                             Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                 Name        Sex        Age
# 1                              Braund, Mr. Owen Harris       male         22
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...     female         38
# 3                               Heikkinen, Miss. Laina     female         26
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)     female         35
# ...

# %%
df.columns = df.iloc[0,:]
df
# Out:
# 0    PassengerId  Survived  Pclass  \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
# 0                                                 Name     Sex  Age  SibSp  \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
df = df.drop(df.index[0])
df
# Out:
# 0   PassengerId Survived Pclass  \
# 1             1        0      3
# 2             2        1      1
# 3             3        1      3
# 4             4        1      1
# 5             5        0      3
# ..          ...      ...    ...
# 887         887        0      2
# 888         888        1      1
# 889         889        0      3
# 890         890        1      1
# 891         891        0      3
#
# 0                                                 Name     Sex  Age SibSp  \
# 1                              Braund, Mr. Owen Harris    male   22     1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38     1
# 3                               Heikkinen, Miss. Laina  female   26     0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35     1
# 5                             Allen, Mr. William Henry    male   35     0
# ..                                                 ...     ...  ...   ...
# ...

# %%
df['Name'].value_counts()
# Out:
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: Name, Length: 891, dtype: int64

# %%
df = df.drop(['Name'], axis=1)

# %%
df
# Out:
# 0   PassengerId Survived Pclass     Sex  Age SibSp Parch            Ticket  \
# 1             1        0      3    male   22     1     0         A/5 21171
# 2             2        1      1  female   38     1     0          PC 17599
# 3             3        1      3  female   26     0     0  STON/O2. 3101282
# 4             4        1      1  female   35     1     0            113803
# 5             5        0      3    male   35     0     0            373450
# ..          ...      ...    ...     ...  ...   ...   ...               ...
# 887         887        0      2    male   27     0     0            211536
# 888         888        1      1  female   19     0     0            112053
# 889         889        0      3  female  NaN     1     2        W./C. 6607
# 890         890        1      1    male   26     0     0            111369
# 891         891        0      3    male   32     0     0            370376
#
# 0       Fare Cabin Embarked
# 1       7.25   NaN        S
# ...

# %%
df = df.drop(['PassengerId'], axis=1)

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
df.isna().sum()
# Out:
# 0
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ### Too many NaN in Cabin --> Drop the column
# ### Fair amount of NaN in Age --> Assign the average age
# ### Only 2 Nan in Embarked --> Drop those 2 rows

# %%
df = df.drop(['Cabin'], axis=1)

# %%
df = df[df['Embarked'].notna()]

# %%
df
# Out:
# 0   Survived Pclass     Sex  Age SibSp Parch            Ticket     Fare  \
# 1          0      3    male   22     1     0         A/5 21171     7.25
# 2          1      1  female   38     1     0          PC 17599  71.2833
# 3          1      3  female   26     0     0  STON/O2. 3101282    7.925
# 4          1      1  female   35     1     0            113803     53.1
# 5          0      3    male   35     0     0            373450     8.05
# ..       ...    ...     ...  ...   ...   ...               ...      ...
# 887        0      2    male   27     0     0            211536       13
# 888        1      1  female   19     0     0            112053       30
# 889        0      3  female  NaN     1     2        W./C. 6607    23.45
# 890        1      1    male   26     0     0            111369       30
# 891        0      3    male   32     0     0            370376     7.75
#
# 0   Embarked
# 1          S
# 2          C
# 3          S
# 4          S
# 5          S
# ..       ...
# ...

# %%
meanAge = int(df['Age'].mean())

# %%
df['Age'] = df['Age'].fillna(meanAge)

# %%
df
# Out:
# 0   Survived Pclass     Sex   Age SibSp Parch            Ticket     Fare  \
# 1          0      3    male  22.0     1     0         A/5 21171     7.25
# 2          1      1  female  38.0     1     0          PC 17599  71.2833
# 3          1      3  female  26.0     0     0  STON/O2. 3101282    7.925
# 4          1      1  female  35.0     1     0            113803     53.1
# 5          0      3    male  35.0     0     0            373450     8.05
# ..       ...    ...     ...   ...   ...   ...               ...      ...
# 887        0      2    male  27.0     0     0            211536       13
# 888        1      1  female  19.0     0     0            112053       30
# 889        0      3  female  29.0     1     2        W./C. 6607    23.45
# 890        1      1    male  26.0     0     0            111369       30
# 891        0      3    male  32.0     0     0            370376     7.75
#
# 0   Embarked
# 1          S
# 2          C
# 3          S
# 4          S
# 5          S
# ...

# %%
df['Ticket'] = df['Ticket'].astype(str)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

le.fit(df['Sex'])
sex = le.transform(df['Sex']).tolist()
df['Sex'] = sex

le.fit(df['Ticket'])
ticket = le.transform(df['Ticket']).tolist()
df['Ticket'] = ticket

le.fit(df['Embarked'])
embarked = le.transform(df['Embarked']).tolist()
df['Embarked'] = embarked

# %%
df
# Out:
# 0   Survived Pclass  Sex   Age SibSp Parch  Ticket     Fare  Embarked
# 1          0      3    1  22.0     1     0     522     7.25         2
# 2          1      1    0  38.0     1     0     595  71.2833         0
# 3          1      3    0  26.0     0     0     668    7.925         2
# 4          1      1    0  35.0     1     0      48     53.1         2
# 5          0      3    1  35.0     0     0     471     8.05         2
# ..       ...    ...  ...   ...   ...   ...     ...      ...       ...
# 887        0      2    1  27.0     0     0     100       13         2
# 888        1      1    0  19.0     0     0      14       30         2
# 889        0      3    0  29.0     1     2     674    23.45         2
# 890        1      1    1  26.0     0     0       8       30         0
# 891        0      3    1  32.0     0     0     465     7.75         1
#
# [889 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

X = df[['Pclass','Sex','Age','SibSp','Ticket','Fare','Embarked']]
y = df['Survived']

y = y.astype(bool)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
import numpy as np
from sklearn.datasets import make_regression
from sklearn.model_selection import KFold, cross_val_predict, cross_val_score
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns

X_array = X.to_numpy()
y_array = y.to_numpy()

X_train_array = X_train.to_numpy()
X_test_array = X_test.to_numpy()
y_train_array = y_train.to_numpy()
y_test_array = y_test.to_numpy()

# %%
def scoreResults(model, x_train, x_test, y_train, y_test):

    y_train_predict = model.predict(x_train)
    y_test_predict = model.predict(x_test)

    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)

    mse_train = metrics.mean_squared_error(y_train, y_train_predict)
    mse_test = metrics.mean_squared_error(y_test, y_test_predict)

    return [r2_train, r2_test, mse_train, mse_test]

scores = []
lr_cv = LogisticRegression()
k = 10
cv = KFold(n_splits=k)
for train_index, test_index in cv.split(X_array):
    # print("Train Index: ", train_index, "\n")
    # print("Test Index: ", test_index)
    X_train_array = X_array[train_index]
    X_test_array = X_array[test_index]
    y_train_array = y_array[train_index]
    y_test_array = y_array[test_index]
    
    y_train_array = y_train_array.astype(int)
    y_test_array = y_test_array.astype(int)
    
    lr_cv.fit(X_train, y_train)

    result = scoreResults(lr_cv
                          ,X_train_array
                          ,X_test_array
                          ,y_train_array
                          ,y_test_array)

    print(f"Train R2 Score: {result[0]:.4f} MSE: {result[2]:.4f}")
    print(f"Test R2 Score: {result[1]:9.4f} MSE: {result[3]:.4f}\n")
    iter += 1
    scores.append(lr_cv.score(X_test_array, y_test_array))
# Out:
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)

scores = []
k = 10
cv = KFold(n_splits=k)
for train_index, test_index in cv.split(X_array):
    # print("Train Index: ", train_index, "\n")
    # print("Test Index: ", test_index)
    X_train_array = X_array[train_index]
    X_test_array = X_array[test_index]
    y_train_array = y_array[train_index]
    y_test_array = y_array[test_index]
    
    y_train_array = y_train_array.astype(int)
    y_test_array = y_test_array.astype(int)
    
    lr_cv.fit(X_train, y_train)

    result = scoreResults(dt
                          ,X_train_array
                          ,X_test_array
                          ,y_train_array
                          ,y_test_array)

    print(f"Train R2 Score: {result[0]:.4f} MSE: {result[2]:.4f}")
    print(f"Test R2 Score: {result[1]:9.4f} MSE: {result[3]:.4f}\n")
    iter += 1
    scores.append(dt.score(X_test_array, y_test_array))
# Out:
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.svm import SVC

svc = SVC(kernel='rbf')

svc.fit(X_train,y_train)

scores = []
k = 10
cv = KFold(n_splits=k)
for train_index, test_index in cv.split(X_array):
    # print("Train Index: ", train_index, "\n")
    # print("Test Index: ", test_index)
    X_train_array = X_array[train_index]
    X_test_array = X_array[test_index]
    y_train_array = y_array[train_index]
    y_test_array = y_array[test_index]
    
    y_train_array = y_train_array.astype(int)
    y_test_array = y_test_array.astype(int)
    
    lr_cv.fit(X_train, y_train)

    result = scoreResults(svc
                          ,X_train_array
                          ,X_test_array
                          ,y_train_array
                          ,y_test_array)

    print(f"Train R2 Score: {result[0]:.4f} MSE: {result[2]:.4f}")
    print(f"Test R2 Score: {result[1]:9.4f} MSE: {result[3]:.4f}\n")
    iter += 1
    scores.append(svc.score(X_test_array, y_test_array))
# Out:
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.svm import SVC

svc = SVC(kernel='linear')

svc.fit(X_train,y_train)

scores = []
k = 10
cv = KFold(n_splits=k)
for train_index, test_index in cv.split(X_array):
    # print("Train Index: ", train_index, "\n")
    # print("Test Index: ", test_index)
    X_train_array = X_array[train_index]
    X_test_array = X_array[test_index]
    y_train_array = y_array[train_index]
    y_test_array = y_array[test_index]
    
    y_train_array = y_train_array.astype(int)
    y_test_array = y_test_array.astype(int)
    
    lr_cv.fit(X_train, y_train)

    result = scoreResults(svc
                          ,X_train_array
                          ,X_test_array
                          ,y_train_array
                          ,y_test_array)

    print(f"Train R2 Score: {result[0]:.4f} MSE: {result[2]:.4f}")
    print(f"Test R2 Score: {result[1]:9.4f} MSE: {result[3]:.4f}\n")
    iter += 1
    scores.append(svc.score(X_test_array, y_test_array))
# Out:
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(10, 10, 10, 10), max_iter=1000)

mlp.fit(X_train,y_train)

scores = []
k = 10
cv = KFold(n_splits=k)
for train_index, test_index in cv.split(X_array):
    # print("Train Index: ", train_index, "\n")
    # print("Test Index: ", test_index)
    X_train_array = X_array[train_index]
    X_test_array = X_array[test_index]
    y_train_array = y_array[train_index]
    y_test_array = y_array[test_index]
    
    y_train_array = y_train_array.astype(int)
    y_test_array = y_test_array.astype(int)
    
    lr_cv.fit(X_train, y_train)

    result = scoreResults(mlp
                          ,X_train_array
                          ,X_test_array
                          ,y_train_array
                          ,y_test_array)

    print(f"Train R2 Score: {result[0]:.4f} MSE: {result[2]:.4f}")
    print(f"Test R2 Score: {result[1]:9.4f} MSE: {result[3]:.4f}\n")
    iter += 1
    scores.append(mlp.score(X_test_array, y_test_array))
# Out:
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\halit.erdogan\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
